# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import scipy

# %%
def quantimage(image,k):
  i=np.float32(image).reshape(-1,3)
  #EPS FOR MIN PIXEL VALUE AND MAX ITER FOR MAX PIXEL VALUE
  condition=(cv2.TERM_CRITERIA_EPS+cv2.TERM_CRITERIA_MAX_ITER,20,1.0)
  ret,label,center=cv2.kmeans(i,k,None,condition,10,cv2.KMEANS_RANDOM_CENTERS)
  #10 is for 10 cluster
  center=np.uint8(center)#k centroid has been stored in center
  #unit 8 is special type of data type
  final_img=center[label.flatten()]
  final_img=final_img.reshape(image.shape)
  return final_img

# %%
image=cv2.imread("/content/1.jpg")

# %%
plt.imshow(quantimage(image,5))
plt.show
# Out:
# <function matplotlib.pyplot.show>
